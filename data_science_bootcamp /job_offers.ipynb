# %% [markdown]
# <a href="https://colab.research.google.com/github/rafpank/Colab/blob/main/data_science_bootcamp%20/job_offers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# %%
#url = 'https://www.amazon.pl/'
url = 'https://rocketjobs.pl'
#url = 'https://justjoin.it'

# %%
response = requests.get(url, headers=headers)
print(response)
# Out:
# <Response [200]>

# %%
content = response.text

# %%
print(content)
# Out:
# <!DOCTYPE html><html lang="pl"><head><meta charSet="utf-8"/><meta property="description" content="Twój portal z ofertami pracy"/><meta property="og:title" content="Rocket Jobs"/><meta property="og:type" content="website"/><meta property="og:description" content="Sprawdź nowe oferty pracy i pracuj w swoim zawodzie. Jakie są obecne zarobki? Zobacz aktualne ogłoszenia z wynagrodzeniem." name="description"/><meta property="og:image" content="https://rocketjobs.pl/gfx/rocketjobs/og-fallback-image.png"/><meta property="og:image:width" content="1200"/><meta property="og:image:height" content="630"/><meta property="twitter:image" content="https://rocketjobs.pl/gfx/rocketjobs/og-fallback-image.png"/><meta name="twitter:card" content="summary_large_image"/><meta property="twitter:title" content="Rocket Jobs"/><meta property="twitter:description" content="Sprawdź nowe oferty pracy i pracuj w swoim zawodzie. Jakie są obecne zarobki? Zobacz aktualne ogłoszenia z wynagrodzeniem."/><meta property="
# ...

# %%
soup = BeautifulSoup(content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="pl">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Twój portal z ofertami pracy" property="description"/>
#   <meta content="Rocket Jobs" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Sprawdź nowe oferty pracy i pracuj w swoim zawodzie. Jakie są obecne zarobki? Zobacz aktualne ogłoszenia z wynagrodzeniem." name="description" property="og:description"/>
#   <meta content="https://rocketjobs.pl/gfx/rocketjobs/og-fallback-image.png" property="og:image"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="https://rocketjobs.pl/gfx/rocketjobs/og-fallback-image.png" property="twitter:image"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="Rocket Jobs" property="twitter:title"/>
# ...
