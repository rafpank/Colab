# %% [markdown]
# <a href="https://colab.research.google.com/github/rafpank/Colab/blob/main/data_science_bootcamp%20/wizualizacja_danych/01_matplotlib_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Matplotlib
# Strona biblioteki: https://matplotlib.org
# dokumentacja: https://matplotlib.org/contents.html
# Matplotlib jest podstawową biblioteką do wizualizacji danych w języku Python.
# W celu zainstalowania biblioteki użyj polecenia poniżej:
#
# ```
# !pip instal matplotlib
#
# ```

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure() # Tworzy obiekt reprezentujący wykres
fig.show()

# %% [markdown]
# #Wykres liniowy

# %%
plt.plot ([0, 1], [0, 3])

# %%
import seaborn as sns
sns.set()
plt.plot ([0, 1], [0, 3])

# %%
_ = plt.plot ([0, 1], [0, 3])

# %%
_ = plt.plot ([0, 1], [0, 3], label = 'linia pierwsza', color = 'green') #dodanie atrybutów wykresów

# %%
#żeby wyświetlić legendę
plt.plot ([0, 1], [0, 3], label = 'linia pierwsza', color = 'green')
_ = plt.legend()
