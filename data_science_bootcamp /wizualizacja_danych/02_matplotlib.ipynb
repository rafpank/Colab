# %% [markdown]
# <a href="https://colab.research.google.com/github/rafpank/Colab/blob/main/data_science_bootcamp%20/wizualizacja_danych/02_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('office.jpg') #wczytanie obrazu z pliku i wyświetlenie go w postaci nampy array
img
# Out:
# array([[[117,  98,  56],
#         [117,  98,  56],
#         [116,  97,  55],
#         ...,
#         [ 98,  82,  48],
#         [ 98,  82,  48],
#         [ 95,  79,  45]],
#
#        [[118,  99,  57],
#         [120, 101,  59],
#         [121, 102,  60],
#         ...,
#         [101,  85,  51],
#         [101,  85,  51],
#         [ 97,  81,  47]],
#
#        [[116,  97,  55],
#         [118,  99,  57],
#         [120, 101,  59],
#         ...,
#         [108,  92,  58],
#         [104,  88,  54],
#         [100,  84,  50]],
#
#        ...,
#
#        [[ 84,  65,  22],
#         [ 86,  67,  24],
#         [ 89,  70,  28],
#         ...,
#         [ 58,  35,   1],
#         [ 58,  35,   1],
#         [ 58,  35,   1]],
#
#        [[ 86,  67,  24],
#         [ 87,  68,  25],
#         [ 89,  70,  28],
#         ...,
#         [ 58,  33,   2],
#         [ 58,  33,   2],
#         [ 57,  32,   1]],
#
#        [[ 88,  69,  26],
#         [ 90,  71,  28],
#         [ 91,  72,  30],
# ...

# %%
img.shape #wymiary obrazu. Przez to że jest kolorowy są trzy kanły i mowi o tym trzeci paramentr
# Out:
# (426, 640, 3)

# %%
plt.imshow(img) #wyświetlenie obrazu

# %%
plt.imshow(img)
plt.axis('Off') #wyłączenie osi
# Out:
# (-0.5, 639.5, 425.5, -0.5)

# %% [markdown]
# Wyświetlenie siatki obrazów

# %%
fig = plt.figure(figsize=(12, 10)) #utwórzenie obiektu typu figure oraz ustawienie rozmiaru obiektu
plt.subplot(221) #określenie jaką chcemy mieć siatkę 2 kolumny, 2 wiersze, 1 wykres
plt.imshow(mpimg.imread('office.jpg')) #wczytanie 1 obrazu
plt.subplot(222) #durgi wykres
plt.imshow(mpimg.imread('business.jpg'))
plt.subplot(223) #trzeci wykres
plt.imshow(mpimg.imread('children.jpg'))
plt.subplot(224)
plt.imshow(mpimg.imread('workplace.jpg'))
plt.axis('Off')
# Out:
# (-0.5, 639.5, 425.5, -0.5)

# %%
#Zautomatyzowanie kodu
fig = plt.figure(figsize=(12, 10)) #utwórzenie obiektu typu figure oraz ustawienie rozmiaru obiektu - to zostaje

for idx, img in enumerate(['office.jpg', 'business.jpg', 'children.jpg', 'workplace.jpg']):
  plt.subplot(220 + idx +1)
  plt.imshow(mpimg.imread(img))
  plt.axis('Off')

# %%
fig = plt.figure(figsize=(12, 10)) #utwórzenie obiektu typu figure oraz ustawienie rozmiaru obiektu - to zostaje

for idx, img in enumerate(['office.jpg', 'business.jpg', 'children.jpg', 'workplace.jpg']):
  plt.subplot(140 + idx +1)
  plt.imshow(mpimg.imread(img))
