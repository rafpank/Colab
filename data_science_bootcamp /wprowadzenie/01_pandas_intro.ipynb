# %% [markdown]
# <a href="https://colab.research.google.com/github/rafpank/Colab/blob/main/data_science_bootcamp%20/wprowadzenie/01_pandas_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas
# Podstawowa biblioteka do analizy danych w języku Python
#
# Strona biblioteki: https://pandas.pydata.org
# Żeby zainstalowac bibliotekę:
#
#
# `
# pip install pandas
#  `

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
import numpy as np #biblioteka numpy jest nam potrzebna żeby uzupełnić braki danych

# %% [markdown]
# #Podstawowe struktury danych typu: Series

# %%
s = pd.Series(data=[3, 2, 4, 6])
s
# Out:
# 0    3
# 1    2
# 2    4
# 3    6
# dtype: int64

# %% [markdown]
# Warto zwrócić uwagę że oprócz samej serii danych pojawił nam się też index

# %%
s = pd.Series(data=[3,2,4,6], index=['a','b','c','d'])
s
# Out:
# a    3
# b    2
# c    4
# d    6
# dtype: int64

# %%
s = pd.Series(data=[3,2,4,6], index=['a','b','c','d'], name='sample')
s
# Out:
# a    3
# b    2
# c    4
# d    6
# Name: sample, dtype: int64

# %%
s = pd.Series(data=[3.,2,4,6], index=['a','b','c','d'], name='sample')
s
# Out:
# a    3.0
# b    2.0
# c    4.0
# d    6.0
# Name: sample, dtype: float64

# %%
np.nan #not a number - atrybut ten umożliwia nam wstawiać braki
# Out:
# nan

# %% [markdown]
# a poniżej przykład jak działa np.nan

# %%
s = pd.Series(data=[3., np.nan, 4, 6], index=['a','b','c','d'], name='sample')
s
# Out:
# a    3.0
# b    NaN
# c    4.0
# d    6.0
# Name: sample, dtype: float64

# %% [markdown]
# dzięki NaN, wartość ta nie wpłynie nam na średnią, a np cyfra 0 wpłynie

# %%
s = pd.Series(data=[True, False, False]) #typ bool
s
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
s = pd.Series(data=np.arange(10,20)) #obiekt numpy wstawiający liczby od 10 do 19stu
s
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# 6    16
# 7    17
# 8    18
# 9    19
# dtype: int64

# %%
s = pd.Series(data=np.arange(10, 20), index= pd.date_range(start='20200101', periods=10)) #index zastępujemy datami, określamy od kiedy i ile tych dat ma być
s
# Out:
# 2020-01-01    10
# 2020-01-02    11
# 2020-01-03    12
# 2020-01-04    13
# 2020-01-05    14
# 2020-01-06    15
# 2020-01-07    16
# 2020-01-08    17
# 2020-01-09    18
# 2020-01-10    19
# Freq: D, dtype: int64

# %%
s.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
list(s.index)
# Out:
# [Timestamp('2020-01-01 00:00:00'),
#  Timestamp('2020-01-02 00:00:00'),
#  Timestamp('2020-01-03 00:00:00'),
#  Timestamp('2020-01-04 00:00:00'),
#  Timestamp('2020-01-05 00:00:00'),
#  Timestamp('2020-01-06 00:00:00'),
#  Timestamp('2020-01-07 00:00:00'),
#  Timestamp('2020-01-08 00:00:00'),
#  Timestamp('2020-01-09 00:00:00'),
#  Timestamp('2020-01-10 00:00:00')]

# %%
s = pd.Series(data=['python', 'java', 'sql'], name= 'Languages')
s
# Out:
# 0    python
# 1      java
# 2       sql
# Name: Languages, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.values
# Out:
# array(['python', 'java', 'sql'], dtype=object)

# %%
s.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# Jezli to jest tekst to będzie 'o' jako object, a jeżeli dane to np int64

# %%
s.shape
# Out:
# (10,)

# %% [markdown]
# kształt czyli jedna kolumna (bo to Series) z 10 wierszami

# %% [markdown]
# #Wycinanie
# na początku stworzymy prosty obiekt o nazwie price

# %%
price = pd.Series(data={'Apple': 200, 'CD Projekt': 60, 'Amazon': 1900}) #notowania giełdowe
price
# Out:
# Apple          200
# CD Projekt      60
# Amazon        1900
# dtype: int64

# %%
price = pd.Series(data={'Apple': 200, 'CD Projekt': 60, 'Amazon': 1900, 'KGHM': np.nan}) #notowania giełdowe
price
# Out:
# Apple          200.0
# CD Projekt      60.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %%
price['CD Projekt']
# Out:
# 60

# %%
price['Apple':'Amazon']
# Out:
# Apple          200
# CD Projekt      60
# Amazon        1900
# dtype: int64

# %%
price[1] #wycięcie 2 wiersza bo indexujemy od 0
# Out:
# <ipython-input-26-d0ce9bd634a1>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   price[1] #wycięcie 2 wiersza bo indexujemy od 0
# 60

# %%
price.count() #liczy nam ile mamy ile mamy obiektów (czyli ile mamy wierszy z jakąś wartością)
# Out:
# 3

# %%
price.value_counts(dropna=False) #pokazuje rozkład danych. Czyli pokazuje ile razy wstąpiła wartość np 60. Kiedy ustawimy dropna=False to wskocza nam tez wartości NaN
#bardzo przydatna funkcja kiedy chcemy zbudować histogram
# Out:
# 200.0     1
# 60.0      1
# 1900.0    1
# NaN       1
# Name: count, dtype: int64

# %%
price.sum()
# Out:
# 2160

# %%
price.max()
# Out:
# 1900

# %%
price.std() #odchylenie standardowe
# Out:
# 1024.3046421841502

# %%
price.describe() #podstawowe statystyki nie zwraca elementów typu NaN
# Out:
# count       3.000000
# mean      720.000000
# std      1024.304642
# min        60.000000
# 25%       130.000000
# 50%       200.000000
# 75%      1050.000000
# max      1900.000000
# dtype: float64

# %%
price.nlargest(2) #zwraca dwa największe elementy
# Out:
# Amazon    1900.0
# Apple      200.0
# dtype: float64

# %%
price.nsmallest(1) #zwraca dwa najmniejsze elementy
# Out:
# CD Projekt    60.0
# dtype: float64

# %%
price.rank() #ranking
# Out:
# Apple         2.0
# CD Projekt    1.0
# Amazon        3.0
# KGHM          NaN
# dtype: float64

# %%
price.sort_values() #sortowanie
# Out:
# CD Projekt      60.0
# Apple          200.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %%
price.sort_values(ascending=False) #sortowanie malejące
# Out:
# Amazon        1900.0
# Apple          200.0
# CD Projekt      60.0
# KGHM             NaN
# dtype: float64

# %%
price.apply(lambda x: x * 3.8) #ta funkcja (lambda) pomnoży nasze wartości razy 3.8 czyli kurs dolara
# Out:
# Apple          760.0
# CD Projekt     228.0
# Amazon        7220.0
# KGHM             NaN
# dtype: float64

# %%
price
# Out:
# Apple          200.0
# CD Projekt      60.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %% [markdown]
# zmiany z ceną nie zostały przypisane do obiektu dlatego to nie zmienia tabeli pierwotnej

# %%
price_pln = price.apply(lambda x: x * 3.8)
price_pln
# Out:
# Apple          760.0
# CD Projekt     228.0
# Amazon        7220.0
# KGHM             NaN
# dtype: float64

# %% [markdown]
# #Podstawowe struktury danych: pd.DataFrame
# Czyli inaczej ramka danych

# %%
df = pd.DataFrame(data=[12,12,32])
df
# Out:
#     0
# 0  12
# 1  12
# 2  32

# %%
s = pd.Series(data=[12,12,32], name = 'Series')
s
# Out:
# 0    12
# 1    12
# 2    32
# Name: Series, dtype: int64

# %% [markdown]
# Niby wyglądają tak samo, ale df ma dużo więcej możliwości, ale przedewszystkim możemy dodawać kolejne kolumny

# %%
df = pd.DataFrame(data=[12,12,32], index=['first', 'second', 'third'], columns=['col_1'])
df
# Out:
#         col_1
# first      12
# second     12
# third      32

# %%
df = pd.DataFrame(data={'WIG20': ['PKN ORLEN', 'PKO BP'],
                      'mWIG40': ['Amica', 'Playway']
                      }
                )
df
# Out:
#        WIG20   mWIG40
# 0  PKN ORLEN    Amica
# 1     PKO BP  Playway

# %%
df = pd.DataFrame(data=[[10, 12, 13], [23, 12, 10]], index=['first', 'second'], columns=['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
df.columns #wyświetla listę nazwy kolumn
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
df.index #wyświetla listę nazwy wierszy
# Out:
# Index(['first', 'second'], dtype='object')

# %%
df.values #wyświetla wartości
# Out:
# array([[10, 12, 13],
#        [23, 12, 10]])

# %%
df.info() #wyświetla informacje o obiekcie
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, first to second
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   2 non-null      int64
#  1   col_2   2 non-null      int64
#  2   col_3   2 non-null      int64
# dtypes: int64(3)
# memory usage: 172.0+ bytes

# %% [markdown]
# dzięki df.info() dostaliśmy informacje o tym że jest to obiekt typu DataFrame, zawierający 2 wiersze i 3 kolumny. Następnie nazwy kolumn ilość pełnych wierszy i czy wystepuja non-null, oraz typy danych.

# %%
df.describe() #wyświetla podstawowe statystyki
# Out:
#            col_1  col_2     col_3
# count   2.000000    2.0   2.00000
# mean   16.500000   12.0  11.50000
# std     9.192388    0.0   2.12132
# min    10.000000   12.0  10.00000
# 25%    13.250000   12.0  10.75000
# 50%    16.500000   12.0  11.50000
# 75%    19.750000   12.0  12.25000
# max    23.000000   12.0  13.00000

# %%
df.describe().T #transponowanie dla lepszej wizualizacji
# Out:
#        count  mean       std   min    25%   50%    75%   max
# col_1    2.0  16.5  9.192388  10.0  13.25  16.5  19.75  23.0
# col_2    2.0  12.0  0.000000  12.0  12.00  12.0  12.00  12.0
# col_3    2.0  11.5  2.121320  10.0  10.75  11.5  12.25  13.0

# %% [markdown]
# #Selekcja kolumn i zmiennnych w obiekcie DagaFrame

# %%
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %% [markdown]
# wycinanie danych

# %%
df.col_1 #wycinanie kolumny
# Out:
# first     10
# second    23
# Name: col_1, dtype: int64

# %%
df['col_1'] #wycinanie kolumny
# Out:
# first     10
# second    23
# Name: col_1, dtype: int64

# %%
type(df['col_1']) #tak tez zadziala type(df.col_1)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Jeżeli natomiast chcemy obiekt typu DataFrame a nie Series to musimy użyć podwujnych nawajsów

# %%
df[['col_1']]
# Out:
#         col_1
# first      10
# second     23

# %%
type(df[['col_1']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns = ['a', 'b', 'c'] #zmiana nazw kolumn - od razu zostaną przypisane te nazwy kolumn
df
# Out:
#          a   b   c
# first   10  12  13
# second  23  12  10

# %%
df.a #wycinanie kolumnę po nazwie. Sposób ten nie zawsze będzie działała np kiedy w nazwie jest spacja
# Out:
# first     10
# second    23
# Name: a, dtype: int64

# %%
df['d'] = df.a + df.c #dodanie nowej kolumny 'd' - suma kolumny a z kolumną c
df
# Out:
#          a   b   c   d
# first   10  12  13  23
# second  23  12  10  33

# %%
df
# Out:
#          a   b   c   d
# first   10  12  13  23
# second  23  12  10  33

# %%
df = pd.DataFrame(data=[[10, 12, 13], [23, 12, 10]], index=['first', 'second'], columns=['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %% [markdown]
# metoda 'loc' i 'iloc' wycinanie po nazwach

# %%
df.loc['first'] #wycinanie wiersza po nazwie indexu
# Out:
# col_1    10
# col_2    12
# col_3    13
# Name: first, dtype: int64

# %%
df.loc['first', 'col_2'] #wycinanie konkretnej wartości
# Out:
# 12

# %%
df.loc[:, 'col_2'] #wycinanie całej kolumny
# Out:
# first     12
# second    12
# Name: col_2, dtype: int64

# %%
df.iloc[0] #wycinanie wiersza po jego indexie
# Out:
# col_1    10
# col_2    12
# col_3    13
# Name: first, dtype: int64

# %%
df.iloc[0, 1] #wycinanie konkretnej wartości
# Out:
# 12

# %%
df.iloc[:, 1] #wycinanie całej kolumny
# Out:
# first     12
# second    12
# Name: col_2, dtype: int64
