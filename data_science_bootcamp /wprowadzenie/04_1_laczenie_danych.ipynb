# %% [markdown]
# <a href="https://colab.research.google.com/github/rafpank/Colab/blob/main/data_science_bootcamp%20/wprowadzenie/04_1_laczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
def fetch_fiancial_data(ticker):
  import pandas_datareader.data as web
  return web.DataReader(name=ticker, data_source='stooq')

# %%
apple = fetch_fiancial_data('AAPL')
amazon = fetch_fiancial_data('AMZN')
google = fetch_fiancial_data('GOOGL')
tesla = fetch_fiancial_data('TSLA')

# %%
apple.head()
# Out:
#               Open     High     Low   Close      Volume
# Date
# 2024-10-04  227.90  228.000  224.13  226.80  37345098.0
# 2024-10-03  225.14  226.805  223.32  225.67  34044158.0
# 2024-10-02  225.89  227.370  223.02  226.78  32880605.0
# 2024-10-01  229.52  229.650  223.74  226.21  63285048.0
# 2024-09-30  230.04  233.000  229.65  233.00  54793391.0

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2024-10-04 to 2019-10-09
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1256 non-null   float64
#  1   High    1256 non-null   float64
#  2   Low     1256 non-null   float64
#  3   Close   1256 non-null   float64
#  4   Volume  1256 non-null   float64
# dtypes: float64(5)
# memory usage: 58.9 KB

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2024-10-04 to 2019-10-09
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1256 non-null   float64
#  1   High    1256 non-null   float64
#  2   Low     1256 non-null   float64
#  3   Close   1256 non-null   float64
#  4   Volume  1256 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
apple.columns = [ 'apple_' + col.lower() for col in apple.columns]
amazon.columns = [ 'amazon_' + col.lower() for col in amazon.columns]
google.columns = [ 'google_' + col.lower() for col in google.columns]
tesla.columns = [ 'tesla_' + col.lower() for col in tesla.columns]

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2024-10-04      227.90     228.000     224.13       226.80    37345098.0
# 2024-10-03      225.14     226.805     223.32       225.67    34044158.0
# 2024-10-02      225.89     227.370     223.02       226.78    32880605.0
# 2024-10-01      229.52     229.650     223.74       226.21    63285048.0
# 2024-09-30      230.04     233.000     229.65       233.00    54793391.0

# %% [markdown]
# #Konkatenacja danych
# czyli łączenie danych

# %%
df = pd.concat(objs=[apple, amazon, google, tesla], axis=1)

# %% [markdown]
# Ustawianie wyświetlania tak żeby pozbyć się zapisu wykładniczego czyli np.(E do -10)
#
# funkcja lambda

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}') # dzięki temu ustawimy opcje wyświetlania. W tym wypadku wyrównanie do 2 miejsc po przecinku
df.describe().T #od transponuje opis dla lepszej widocznosci
# Out:
#                 count         mean         std         min         25%  \
# apple_open    1256.00       144.25       41.74       54.92      121.69
# apple_high    1256.00       145.86       41.99       55.10      123.08
# apple_low     1256.00       142.74       41.45       51.71      120.02
# apple_close   1256.00       144.38       41.73       54.57      121.70
# apple_volume  1256.00  94940134.99 54264507.58 24139598.57 59316829.92
# amazon_open   1256.00       141.24       31.27       82.08      114.09
# amazon_high   1256.00       142.97       31.38       83.48      116.65
# amazon_low    1256.00       139.40       31.01       81.30      112.83
# amazon_close  1256.00       141.21       31.17       81.82      114.79
# amazon_volume 1256.00  69598745.56 33675672.09 17626740.00 47851626.75
# google_open   1256.00       113.81       31.74       52.82       88.20
# google_high   1256.00       115.11       31.95       53.35       88.93
# ...

# %%
df.corr() #wsp. korlacji poszczególnych zmiennych
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.58
# apple_high           1.00        1.00       1.00         1.00         -0.58
# apple_low            1.00        1.00       1.00         1.00         -0.59
# apple_close          1.00        1.00       1.00         1.00         -0.59
# apple_volume        -0.58       -0.58      -0.59        -0.59          1.00
# amazon_open          0.51        0.50       0.50         0.50         -0.18
# amazon_high          0.51        0.51       0.51         0.50         -0.17
# amazon_low           0.50        0.50       0.50         0.50         -0.19
# amazon_close         0.50        0.50       0.50         0.50         -0.18
# amazon_volume       -0.45       -0.44      -0.45        -0.45          0.64
# google_open          0.89        0.89       0.89         0.89         -0.55
# ...

# %%
df.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume',
#        'amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume', 'google_open', 'google_high', 'google_low',
#        'google_close', 'google_volume', 'tesla_open', 'tesla_high',
#        'tesla_low', 'tesla_close', 'tesla_volume'],
#       dtype='object')

# %%
closes = [ col for col in df.columns if col.endswith('close') ]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'tesla_close']

# %%
df[closes].corr()
# Out:
#               apple_close  amazon_close  google_close  tesla_close
# apple_close          1.00          0.50          0.89         0.70
# amazon_close         0.50          1.00          0.68         0.48
# google_close         0.89          0.68          1.00         0.67
# tesla_close          0.70          0.48          0.67         1.00

# %%
closes = [ col for col in df.columns if col.endswith('close') or col.endswith('volume') ]
closes
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'tesla_close',
#  'tesla_volume']

# %%
df
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume  \
# Date
# 2024-10-04      227.90      228.00     224.13       226.80   37345098.00
# 2024-10-03      225.14      226.81     223.32       225.67   34044158.00
# 2024-10-02      225.89      227.37     223.02       226.78   32880605.00
# 2024-10-01      229.52      229.65     223.74       226.21   63285048.00
# 2024-09-30      230.04      233.00     229.65       233.00   54793391.00
# ...                ...         ...        ...          ...           ...
# 2019-10-15       57.19       57.49      56.82        56.93   95243634.66
# 2019-10-14       56.83       57.61      56.77        57.06  100919285.19
# 2019-10-11       56.35       57.49      56.20        57.14  173577099.66
# 2019-10-10       55.14       55.75      54.98        55.66  119725783.17
# 2019-10-09       54.92       55.10      54.58        54.92   78662918.26
#
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume  \
# ...

# %%
amazon.head(10)
# Out:
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume
# Date
# 2024-10-04       185.75       187.60      183.60        186.51       41079011
# 2024-10-03       183.04       183.44      180.88        181.96       30204302
# 2024-10-02       184.44       186.60      184.04        184.76       23704056
# 2024-10-01       184.90       186.19      183.45        185.13       36044906
# 2024-09-30       187.14       188.49      184.65        186.33       41680400
# 2024-09-27       190.68       190.90      187.34        187.97       36002316
# 2024-09-26       194.31       194.53      189.54        191.16       36334854
# 2024-09-25       193.75       193.95      192.16        192.53       26391144
# 2024-09-24       194.27       195.37      190.13        193.96       43478926
# 2024-09-23       191.64       194.45      190.57        193.88       36993111

# %% [markdown]
# #Łączenie za pomocą metody 'append'

# %%
amazon_6 = amazon[(amazon.index.month == 6) & (amazon.index.year == 2024)]
amazon_6
# Out:
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume
# Date
# 2024-06-28       197.73       198.85      192.50        193.25       76930192
# 2024-06-27       195.00       199.84      194.20        197.85       74397491
# 2024-06-26       186.92       194.80      186.26        193.61       65103893
# 2024-06-25       186.81       188.84      185.42        186.34       45898475
# 2024-06-24       189.33       191.00      185.33        185.57       50610379
# 2024-06-21       187.80       189.28      185.86        189.08       72931754
# 2024-06-20       182.91       186.51      182.72        186.10       44726779
# 2024-06-18       183.74       184.29      181.43        182.81       36659157
# 2024-06-17       182.52       185.00      181.22        184.06       35601907
# 2024-06-14       183.08       183.72      182.23        183.66       25456410
# 2024-06-13       186.09       187.67      182.67        183.83       39721545
# ...

# %%
apple_06 = apple[(apple.index.month == 6) & (apple.index.year == 2024)]
apple_06
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2024-06-28      215.52      215.82     210.06       210.38   82638257.98
# 2024-06-27      214.44      215.49     212.10       213.85   49830316.97
# 2024-06-26      211.25      214.61     210.40       213.00   66289825.18
# 2024-06-25      208.91      211.14     208.37       208.83   56779512.09
# 2024-06-24      207.48      212.45     206.35       207.90   80820444.36
# 2024-06-21      210.15      211.65     206.87       207.25  246706576.11
# 2024-06-20      213.68      213.99     208.61       209.44   86272192.25
# 2024-06-18      217.34      218.38     212.75       214.04   80035785.20
# 2024-06-17      213.12      218.70     212.47       216.42   93836786.85
# 2024-06-14      213.60      214.92     211.06       212.24   70203912.35
# 2024-06-13      214.49      216.50     211.35       213.99   97976001.29
# 2024-06-12      207.13      219.94     206.66       212.82  198363625.72
# ...

# %%
amazon_7 = amazon[(amazon.index.month == 7) & (amazon.index.year == 2024)]
amazon_7
# Out:
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume
# Date
# 2024-07-31       185.05       187.94      184.46        186.98       41667326
# 2024-07-30       184.72       185.86      179.38        181.71       39508574
# 2024-07-29       183.84       184.75      182.38        183.20       33270123
# 2024-07-26       180.39       183.19      180.24        182.50       29505964
# 2024-07-25       182.91       183.90      176.80        179.85       44464163
# 2024-07-24       183.20       185.45      180.41        180.83       41532360
# 2024-07-23       184.10       189.39      183.56        186.41       47537670
# 2024-07-22       185.00       185.06      182.48        182.55       39931923
# 2024-07-19       181.14       184.93      180.11        183.13       43081829
# 2024-07-18       189.59       189.68      181.45        183.75       51043626
# 2024-07-17       191.35       191.58      185.99        187.93       48076139
# ...

# %% [markdown]
# Połącze 2 amazony z 2 kolejnych miesięcy

# %%
amazon_6.append(amazon_7) #wygląda na to że metoda 'append' została wycofana od wersji 1.4.0 Pandas
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-dcba165afc06> in <cell line: 1>()
# ----> 1 amazon_6.append(amazon_7)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
result = pd.concat([amazon_6, amazon_7])

# %%
result
# Out:
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume
# Date
# 2024-06-28       197.73       198.85      192.50        193.25       76930192
# 2024-06-27       195.00       199.84      194.20        197.85       74397491
# 2024-06-26       186.92       194.80      186.26        193.61       65103893
# 2024-06-25       186.81       188.84      185.42        186.34       45898475
# 2024-06-24       189.33       191.00      185.33        185.57       50610379
# 2024-06-21       187.80       189.28      185.86        189.08       72931754
# 2024-06-20       182.91       186.51      182.72        186.10       44726779
# 2024-06-18       183.74       184.29      181.43        182.81       36659157
# 2024-06-17       182.52       185.00      181.22        184.06       35601907
# 2024-06-14       183.08       183.72      182.23        183.66       25456410
# 2024-06-13       186.09       187.67      182.67        183.83       39721545
# ...
