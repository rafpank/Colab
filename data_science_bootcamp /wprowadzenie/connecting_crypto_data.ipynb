# %% [markdown]
# <a href="https://colab.research.google.com/github/rafpank/Colab/blob/main/data_science_bootcamp%20/wprowadzenie/connecting_crypto_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
url = 'https://api.binance.com/api/v3/ticker/price?symbol=BTCUSDT'
response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'code': 0, 'msg': "Service unavailable from a restricted location according to 'b. Eligibility' in https://www.binance.com/en/terms. Please contact customer service if you believe you received this message in error."}

# %%
df = pd.read_csv('btc.csv')
df
# Out:
#                 Timestamp      Open      High       Low     Close  \
# 0     2017-08-17 00:00:00   4261.48   4485.39   4200.74   4285.08
# 1     2017-08-18 00:00:00   4285.08   4371.52   3938.77   4108.37
# 2     2017-08-19 00:00:00   4108.37   4184.69   3850.00   4139.98
# 3     2017-08-20 00:00:00   4120.98   4211.08   4032.62   4086.29
# 4     2017-08-21 00:00:00   4069.13   4119.62   3911.79   4016.00
# ...                   ...       ...       ...       ...       ...
# 2606  2024-10-05 00:00:00  62086.00  62370.56  61689.26  62058.00
# 2607  2024-10-06 00:00:00  62058.01  62975.00  61798.97  62819.91
# 2608  2024-10-07 00:00:00  62819.91  64478.19  62128.00  62224.00
# 2609  2024-10-08 00:00:00  62224.01  63200.00  61860.31  62160.49
# 2610  2024-10-09 00:00:00  62160.50  62542.06  62002.50  62509.36
#
#             Volume
# 0       795.150377
# 1      1199.888264
# 2       381.309763
# 3       467.083022
# 4       691.743060
# ...            ...
# 2606   7807.461410
# ...

# %%
bnb = pd.read_csv('bnb.csv')
eth = pd.read_csv('eth.csv')
pepe = pd.read_csv('pepe.csv')

# %%
#df.set_index('Timestamp', inplace=True)
df
# Out:
#                          Open      High       Low     Close        Volume
# Timestamp
# 2017-08-17 00:00:00   4261.48   4485.39   4200.74   4285.08    795.150377
# 2017-08-18 00:00:00   4285.08   4371.52   3938.77   4108.37   1199.888264
# 2017-08-19 00:00:00   4108.37   4184.69   3850.00   4139.98    381.309763
# 2017-08-20 00:00:00   4120.98   4211.08   4032.62   4086.29    467.083022
# 2017-08-21 00:00:00   4069.13   4119.62   3911.79   4016.00    691.743060
# ...                       ...       ...       ...       ...           ...
# 2024-10-05 00:00:00  62086.00  62370.56  61689.26  62058.00   7807.461410
# 2024-10-06 00:00:00  62058.01  62975.00  61798.97  62819.91   8906.861770
# 2024-10-07 00:00:00  62819.91  64478.19  62128.00  62224.00  25966.185200
# 2024-10-08 00:00:00  62224.01  63200.00  61860.31  62160.49  19702.223710
# 2024-10-09 00:00:00  62160.50  62542.06  62002.50  62509.36   3360.891820
#
# [2611 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2611 entries, 2017-08-17 00:00:00 to 2024-10-09 00:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2611 non-null   float64
#  1   High    2611 non-null   float64
#  2   Low     2611 non-null   float64
#  3   Close   2611 non-null   float64
#  4   Volume  2611 non-null   float64
# dtypes: float64(5)
# memory usage: 122.4+ KB

# %%
eth
# Out:
#                 Timestamp     Open     High      Low    Close        Volume
# 0     2017-08-17 00:00:00   301.13   312.18   298.00   302.00    7030.71034
# 1     2017-08-18 00:00:00   302.00   311.79   283.94   293.96    9537.84646
# 2     2017-08-19 00:00:00   293.31   299.90   278.00   290.91    2146.19773
# 3     2017-08-20 00:00:00   289.41   300.53   282.85   299.10    2510.13871
# 4     2017-08-21 00:00:00   299.10   346.52   294.60   323.29    5219.44542
# ...                   ...      ...      ...      ...      ...           ...
# 2606  2024-10-05 00:00:00  2414.41  2428.23  2390.05  2414.66  103740.23160
# 2607  2024-10-06 00:00:00  2414.66  2457.80  2407.00  2440.03  105752.70960
# 2608  2024-10-07 00:00:00  2440.02  2521.00  2403.00  2422.71  300459.54070
# 2609  2024-10-08 00:00:00  2422.70  2466.66  2401.18  2440.89  201358.33120
# 2610  2024-10-09 00:00:00  2440.88  2473.61  2427.44  2450.00   47275.35550
#
# [2611 rows x 6 columns]

# %%
eth.set_index('Timestamp', inplace=True)
eth
# Out:
#                         Open     High      Low    Close        Volume
# Timestamp
# 2017-08-17 00:00:00   301.13   312.18   298.00   302.00    7030.71034
# 2017-08-18 00:00:00   302.00   311.79   283.94   293.96    9537.84646
# 2017-08-19 00:00:00   293.31   299.90   278.00   290.91    2146.19773
# 2017-08-20 00:00:00   289.41   300.53   282.85   299.10    2510.13871
# 2017-08-21 00:00:00   299.10   346.52   294.60   323.29    5219.44542
# ...                      ...      ...      ...      ...           ...
# 2024-10-05 00:00:00  2414.41  2428.23  2390.05  2414.66  103740.23160
# 2024-10-06 00:00:00  2414.66  2457.80  2407.00  2440.03  105752.70960
# 2024-10-07 00:00:00  2440.02  2521.00  2403.00  2422.71  300459.54070
# 2024-10-08 00:00:00  2422.70  2466.66  2401.18  2440.89  201358.33120
# 2024-10-09 00:00:00  2440.88  2473.61  2427.44  2450.00   47275.35550
#
# [2611 rows x 5 columns]

# %%
bnb.set_index('Timestamp', inplace=True)
bnb
# Out:
#                          Open      High       Low     Close      Volume
# Timestamp
# 2017-11-06 00:00:00    1.5000    1.7990    0.5000    1.5710  120615.340
# 2017-11-07 00:00:00    1.5710    1.8000    1.5389    1.8000  134129.730
# 2017-11-08 00:00:00    1.7901    1.9900    1.7479    1.9889  347290.260
# 2017-11-09 00:00:00    1.9781    2.1997    1.9000    1.9900  287037.200
# 2017-11-10 00:00:00    1.9900    2.0200    1.6019    1.7133  484658.900
# ...                       ...       ...       ...       ...         ...
# 2024-10-05 00:00:00  555.3000  565.2000  551.6000  563.0000  124906.382
# 2024-10-06 00:00:00  563.0000  571.9000  561.1000  570.3000  106787.340
# 2024-10-07 00:00:00  570.4000  581.8000  563.5000  564.3000  213046.676
# 2024-10-08 00:00:00  564.4000  586.8000  559.5000  580.8000  286276.177
# 2024-10-09 00:00:00  580.8000  583.1000  573.1000  581.8000  106837.222
#
# [2530 rows x 5 columns]

# %%
pepe.set_index('Timestamp', inplace=True)
pepe
# Out:
#                           Open       High        Low      Close  \
# Timestamp
# 2023-05-05 00:00:00  0.0000020  0.0000044  0.0000020  0.0000037
# 2023-05-06 00:00:00  0.0000037  0.0000039  0.0000023  0.0000026
# 2023-05-07 00:00:00  0.0000026  0.0000031  0.0000024  0.0000028
# 2023-05-08 00:00:00  0.0000028  0.0000028  0.0000015  0.0000019
# 2023-05-09 00:00:00  0.0000019  0.0000021  0.0000017  0.0000020
# ...                        ...        ...        ...        ...
# 2024-10-05 00:00:00  0.0000094  0.0000096  0.0000092  0.0000094
# 2024-10-06 00:00:00  0.0000094  0.0000103  0.0000092  0.0000102
# 2024-10-07 00:00:00  0.0000102  0.0000108  0.0000098  0.0000098
# 2024-10-08 00:00:00  0.0000098  0.0000101  0.0000093  0.0000095
# 2024-10-09 00:00:00  0.0000095  0.0000098  0.0000094  0.0000098
#
#                                       Volume
# Timestamp
# 2023-05-05 00:00:00   46108639000543.0000000
# 2023-05-06 00:00:00  108184587925547.0000000
# ...

# %%
pepe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 524 entries, 2023-05-05 00:00:00 to 2024-10-09 00:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    524 non-null    float64
#  1   High    524 non-null    float64
#  2   Low     524 non-null    float64
#  3   Close   524 non-null    float64
#  4   Volume  524 non-null    float64
# dtypes: float64(5)
# memory usage: 24.6+ KB

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2611 entries, 2017-08-17 00:00:00 to 2024-10-09 00:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2611 non-null   float64
#  1   High    2611 non-null   float64
#  2   Low     2611 non-null   float64
#  3   Close   2611 non-null   float64
#  4   Volume  2611 non-null   float64
# dtypes: float64(5)
# memory usage: 122.4+ KB

# %%
df.columns = ['BTC_' + col.lower() for col in df.columns]
df
# Out:
#                      BTC_open  BTC_high   BTC_low  BTC_close    BTC_volume
# Timestamp
# 2017-08-17 00:00:00   4261.48   4485.39   4200.74    4285.08    795.150377
# 2017-08-18 00:00:00   4285.08   4371.52   3938.77    4108.37   1199.888264
# 2017-08-19 00:00:00   4108.37   4184.69   3850.00    4139.98    381.309763
# 2017-08-20 00:00:00   4120.98   4211.08   4032.62    4086.29    467.083022
# 2017-08-21 00:00:00   4069.13   4119.62   3911.79    4016.00    691.743060
# ...                       ...       ...       ...        ...           ...
# 2024-10-05 00:00:00  62086.00  62370.56  61689.26   62058.00   7807.461410
# 2024-10-06 00:00:00  62058.01  62975.00  61798.97   62819.91   8906.861770
# 2024-10-07 00:00:00  62819.91  64478.19  62128.00   62224.00  25966.185200
# 2024-10-08 00:00:00  62224.01  63200.00  61860.31   62160.49  19702.223710
# 2024-10-09 00:00:00  62160.50  62542.06  62002.50   62509.36   3360.891820
#
# [2611 rows x 5 columns]

# %%
eth.columns = [ 'ETH_' + col.lower() for col in eth.columns]
eth
# Out:
#                      ETH_open  ETH_high  ETH_low  ETH_close    ETH_volume
# Timestamp
# 2017-08-17 00:00:00    301.13    312.18   298.00     302.00    7030.71034
# 2017-08-18 00:00:00    302.00    311.79   283.94     293.96    9537.84646
# 2017-08-19 00:00:00    293.31    299.90   278.00     290.91    2146.19773
# 2017-08-20 00:00:00    289.41    300.53   282.85     299.10    2510.13871
# 2017-08-21 00:00:00    299.10    346.52   294.60     323.29    5219.44542
# ...                       ...       ...      ...        ...           ...
# 2024-10-05 00:00:00   2414.41   2428.23  2390.05    2414.66  103740.23160
# 2024-10-06 00:00:00   2414.66   2457.80  2407.00    2440.03  105752.70960
# 2024-10-07 00:00:00   2440.02   2521.00  2403.00    2422.71  300459.54070
# 2024-10-08 00:00:00   2422.70   2466.66  2401.18    2440.89  201358.33120
# 2024-10-09 00:00:00   2440.88   2473.61  2427.44    2450.00   47275.35550
#
# [2611 rows x 5 columns]

# %%
bnb.columns = [ 'BNB_' + col.lower() for col in bnb.columns]
bnb
# Out:
#                      BNB_open  BNB_high   BNB_low  BNB_close  BNB_volume
# Timestamp
# 2017-11-06 00:00:00    1.5000    1.7990    0.5000     1.5710  120615.340
# 2017-11-07 00:00:00    1.5710    1.8000    1.5389     1.8000  134129.730
# 2017-11-08 00:00:00    1.7901    1.9900    1.7479     1.9889  347290.260
# 2017-11-09 00:00:00    1.9781    2.1997    1.9000     1.9900  287037.200
# 2017-11-10 00:00:00    1.9900    2.0200    1.6019     1.7133  484658.900
# ...                       ...       ...       ...        ...         ...
# 2024-10-05 00:00:00  555.3000  565.2000  551.6000   563.0000  124906.382
# 2024-10-06 00:00:00  563.0000  571.9000  561.1000   570.3000  106787.340
# 2024-10-07 00:00:00  570.4000  581.8000  563.5000   564.3000  213046.676
# 2024-10-08 00:00:00  564.4000  586.8000  559.5000   580.8000  286276.177
# 2024-10-09 00:00:00  580.8000  583.1000  573.1000   581.8000  106837.222
#
# [2530 rows x 5 columns]

# %%
pepe.columns = ['PEPE_' + col.lower() for col in pepe.columns]
pepe.head(10)
# Out:
#                      PEPE_open  PEPE_high  PEPE_low  PEPE_close   PEPE_volume
# Timestamp
# 2023-05-05 00:00:00   0.000002   0.000004  0.000002    0.000004  4.610864e+13
# 2023-05-06 00:00:00   0.000004   0.000004  0.000002    0.000003  1.081846e+14
# 2023-05-07 00:00:00   0.000003   0.000003  0.000002    0.000003  6.507744e+13
# 2023-05-08 00:00:00   0.000003   0.000003  0.000002    0.000002  1.402375e+14
# 2023-05-09 00:00:00   0.000002   0.000002  0.000002    0.000002  8.440852e+13
# 2023-05-10 00:00:00   0.000002   0.000002  0.000002    0.000002  6.237661e+13
# 2023-05-11 00:00:00   0.000002   0.000002  0.000001    0.000001  1.024782e+14
# 2023-05-12 00:00:00   0.000001   0.000002  0.000001    0.000002  1.831172e+14
# 2023-05-13 00:00:00   0.000002   0.000002  0.000002    0.000002  1.608453e+14
# 2023-05-14 00:00:00   0.000002   0.000002  0.000002    0.000002  6.833063e+13

# %% [markdown]
# #Łączenie tabel
# metodą konkatenacji (dostępna w bibliotece Pandas) w której podajemy LISTĘ (objs) obiektów (w tym przypadku listę DataFrame) i połączymy je względem osi poziomej (axis = 1)

# %%
df_con = pd.concat(objs=[df, eth, bnb, pepe], axis=1)

# %%
df_con
# Out:
#                      BTC_open  BTC_high   BTC_low  BTC_close    BTC_volume  \
# Timestamp
# 2017-08-17 00:00:00   4261.48   4485.39   4200.74    4285.08    795.150377
# 2017-08-18 00:00:00   4285.08   4371.52   3938.77    4108.37   1199.888264
# 2017-08-19 00:00:00   4108.37   4184.69   3850.00    4139.98    381.309763
# 2017-08-20 00:00:00   4120.98   4211.08   4032.62    4086.29    467.083022
# 2017-08-21 00:00:00   4069.13   4119.62   3911.79    4016.00    691.743060
# ...                       ...       ...       ...        ...           ...
# 2024-10-05 00:00:00  62086.00  62370.56  61689.26   62058.00   7807.461410
# 2024-10-06 00:00:00  62058.01  62975.00  61798.97   62819.91   8906.861770
# 2024-10-07 00:00:00  62819.91  64478.19  62128.00   62224.00  25966.185200
# 2024-10-08 00:00:00  62224.01  63200.00  61860.31   62160.49  19702.223710
# 2024-10-09 00:00:00  62160.50  62542.06  62002.50   62509.36   3360.891820
#
# ...

# %%
df_con.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2611 entries, 2017-08-17 00:00:00 to 2024-10-09 00:00:00
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   BTC_open     2611 non-null   float64
#  1   BTC_high     2611 non-null   float64
#  2   BTC_low      2611 non-null   float64
#  3   BTC_close    2611 non-null   float64
#  4   BTC_volume   2611 non-null   float64
#  5   ETH_open     2611 non-null   float64
#  6   ETH_high     2611 non-null   float64
#  7   ETH_low      2611 non-null   float64
#  8   ETH_close    2611 non-null   float64
#  9   ETH_volume   2611 non-null   float64
#  10  BNB_open     2530 non-null   float64
#  11  BNB_high     2530 non-null   float64
#  12  BNB_low      2530 non-null   float64
#  13  BNB_close    2530 non-null   float64
#  14  BNB_volume   2530 non-null   float64
#  15  PEPE_open    524 non-null    float64
#  16  PEPE_high    524 non-null    float64
# ...

# %%
df_con.describe().T
# Out:
#                count               mean                std               min  \
# BTC_open     2611.00           25137.26           19546.37           3188.01
# BTC_high     2611.00           25754.13           19988.63           3276.50
# BTC_low      2611.00           24465.93           19064.46           2817.00
# BTC_close    2611.00           25159.63           19555.80           3189.02
# BTC_volume   2611.00           69148.12           81086.65            228.11
# ETH_open     2611.00            1398.18            1201.93             83.75
# ETH_high     2611.00            1439.52            1234.58             85.00
# ETH_low      2611.00            1351.46            1164.03             81.79
# ETH_close    2611.00            1399.00            1201.92             83.76
# ETH_volume   2611.00          525242.72          466616.96           1060.57
# BNB_open     2530.00             204.81             200.43              1.50
# ...

# %%
pd.set_option('display.float_format', lambda x: f'{x: .2f}') #ustwienie 2 miejsc po przecinku dzięki funkcji lambda

df_con.describe().T
# Out:
#                count               mean                std               min  \
# BTC_open     2611.00           25137.26           19546.37           3188.01
# BTC_high     2611.00           25754.13           19988.63           3276.50
# BTC_low      2611.00           24465.93           19064.46           2817.00
# BTC_close    2611.00           25159.63           19555.80           3189.02
# BTC_volume   2611.00           69148.12           81086.65            228.11
# ETH_open     2611.00            1398.18            1201.93             83.75
# ETH_high     2611.00            1439.52            1234.58             85.00
# ETH_low      2611.00            1351.46            1164.03             81.79
# ETH_close    2611.00            1399.00            1201.92             83.76
# ETH_volume   2611.00          525242.72          466616.96           1060.57
# BNB_open     2530.00             204.81             200.43              1.50
# ...

# %%
df_con.corr() #sprawdzenie korelacji
# Out:
#              BTC_open  BTC_high  BTC_low  BTC_close  BTC_volume  ETH_open  \
# BTC_open         1.00      1.00     1.00       1.00       -0.04      0.93
# BTC_high         1.00      1.00     1.00       1.00       -0.03      0.93
# BTC_low          1.00      1.00     1.00       1.00       -0.04      0.93
# BTC_close        1.00      1.00     1.00       1.00       -0.04      0.93
# BTC_volume      -0.04     -0.03    -0.04      -0.04        1.00      0.02
# ETH_open         0.93      0.93     0.93       0.93        0.02      1.00
# ETH_high         0.93      0.93     0.93       0.93        0.03      1.00
# ETH_low          0.93      0.93     0.93       0.93        0.02      1.00
# ETH_close        0.93      0.93     0.93       0.93        0.02      1.00
# ETH_volume       0.09      0.10     0.07       0.09        0.46      0.04
# BNB_open         0.92      0.91     0.92       0.91        0.10      0.95
# BNB_high         0.92      0.92     0.92       0.92        0.10      0.95
# ...

# %%
df_con.columns
# Out:
# Index(['BTC_open', 'BTC_high', 'BTC_low', 'BTC_close', 'BTC_volume',
#        'ETH_open', 'ETH_high', 'ETH_low', 'ETH_close', 'ETH_volume',
#        'BNB_open', 'BNB_high', 'BNB_low', 'BNB_close', 'BNB_volume',
#        'PEPE_open', 'PEPE_high', 'PEPE_low', 'PEPE_close', 'PEPE_volume'],
#       dtype='object')

# %%
closes = [col for col in df_con.columns if col.endswith('close')] # wyciągnięcie nazw dla zamkniecia sesji
closes
# Out:
# ['BTC_close', 'ETH_close', 'BNB_close', 'PEPE_close']

# %%
df_con[closes] # wyciągnięcie wszystkich danych zamknięcia dla kazdej waluty w celu zrobienia
# Out:
#                      BTC_close  ETH_close  BNB_close  PEPE_close
# Timestamp
# 2017-08-17 00:00:00    4285.08     302.00        NaN         NaN
# 2017-08-18 00:00:00    4108.37     293.96        NaN         NaN
# 2017-08-19 00:00:00    4139.98     290.91        NaN         NaN
# 2017-08-20 00:00:00    4086.29     299.10        NaN         NaN
# 2017-08-21 00:00:00    4016.00     323.29        NaN         NaN
# ...                        ...        ...        ...         ...
# 2024-10-05 00:00:00   62058.00    2414.66     563.00        0.00
# 2024-10-06 00:00:00   62819.91    2440.03     570.30        0.00
# 2024-10-07 00:00:00   62224.00    2422.71     564.30        0.00
# 2024-10-08 00:00:00   62160.49    2440.89     580.80        0.00
# 2024-10-09 00:00:00   62509.36    2450.00     581.80        0.00
#
# [2611 rows x 4 columns]

# %%
df_con[closes].corr()
# Out:
#             BTC_close  ETH_close  BNB_close  PEPE_close
# BTC_close        1.00       0.93       0.92        0.87
# ETH_close        0.93       1.00       0.95        0.83
# BNB_close        0.92       0.95       1.00        0.93
# PEPE_close       0.87       0.83       0.93        1.00

# %%
close_values = [col for col in df_con.columns if col.endswith('volume')]
close_values
# Out:
# ['BTC_volume', 'ETH_volume', 'BNB_volume', 'PEPE_volume']

# %%
df_con[close_values]
# Out:
#                      BTC_volume  ETH_volume  BNB_volume        PEPE_volume
# Timestamp
# 2017-08-17 00:00:00      795.15     7030.71         NaN                NaN
# 2017-08-18 00:00:00     1199.89     9537.85         NaN                NaN
# 2017-08-19 00:00:00      381.31     2146.20         NaN                NaN
# 2017-08-20 00:00:00      467.08     2510.14         NaN                NaN
# 2017-08-21 00:00:00      691.74     5219.45         NaN                NaN
# ...                         ...         ...         ...                ...
# 2024-10-05 00:00:00     7807.46   103740.23   124906.38  21837595780367.00
# 2024-10-06 00:00:00     8906.86   105752.71   106787.34  29884884704265.00
# 2024-10-07 00:00:00    25966.19   300459.54   213046.68  43987938222565.00
# 2024-10-08 00:00:00    19702.22   201358.33   286276.18  28331793957112.00
# 2024-10-09 00:00:00     3360.89    47275.36   106837.22   5703467555788.00
#
# [2611 rows x 4 columns]

# %%
df_con[close_values].corr()
# Out:
#              BTC_volume  ETH_volume  BNB_volume  PEPE_volume
# BTC_volume         1.00        0.46       -0.01         0.56
# ETH_volume         0.46        1.00        0.44         0.57
# BNB_volume        -0.01        0.44        1.00         0.37
# PEPE_volume        0.56        0.57        0.37         1.00

# %%
(df_con[close_values]+ df_con[closes]).corr() #to nie to o co mi c
# Out:
#              BNB_close  BNB_volume  BTC_close  BTC_volume  ETH_close  \
# BNB_close          NaN         NaN        NaN         NaN        NaN
# BNB_volume         NaN         NaN        NaN         NaN        NaN
# BTC_close          NaN         NaN        NaN         NaN        NaN
# BTC_volume         NaN         NaN        NaN         NaN        NaN
# ETH_close          NaN         NaN        NaN         NaN        NaN
# ETH_volume         NaN         NaN        NaN         NaN        NaN
# PEPE_close         NaN         NaN        NaN         NaN        NaN
# PEPE_volume        NaN         NaN        NaN         NaN        NaN
#
#              ETH_volume  PEPE_close  PEPE_volume
# BNB_close           NaN         NaN          NaN
# BNB_volume          NaN         NaN          NaN
# BTC_close           NaN         NaN          NaN
# BTC_volume          NaN         NaN          NaN
# ETH_close           NaN         NaN          NaN
# ...

# %%
closes_values = [col for col in df_con.columns if col.endswith('close') or col.endswith('volume') ] # wyciągnięcie nazw dla zamkniecia sesjii i wolumenu
closes_values
# Out:
# ['BTC_close',
#  'BTC_volume',
#  'ETH_close',
#  'ETH_volume',
#  'BNB_close',
#  'BNB_volume',
#  'PEPE_close',
#  'PEPE_volume']

# %%
df_con[closes_values].corr()
# Out:
#              BTC_close  BTC_volume  ETH_close  ETH_volume  BNB_close  \
# BTC_close         1.00       -0.04       0.93        0.09       0.92
# BTC_volume       -0.04        1.00       0.02        0.46       0.10
# ETH_close         0.93        0.02       1.00        0.03       0.95
# ETH_volume        0.09        0.46       0.03        1.00       0.01
# BNB_close         0.92        0.10       0.95        0.01       1.00
# BNB_volume       -0.20       -0.01      -0.30        0.44      -0.35
# PEPE_close        0.87       -0.16       0.83        0.04       0.93
# PEPE_volume       0.24        0.56       0.32        0.57       0.19
#
#              BNB_volume  PEPE_close  PEPE_volume
# BTC_close         -0.20        0.87         0.24
# BTC_volume        -0.01       -0.16         0.56
# ETH_close         -0.30        0.83         0.32
# ETH_volume         0.44        0.04         0.57
# BNB_close         -0.35        0.93         0.19
# ...

# %%
btc =df
btc
# Out:
#                      BTC_open  BTC_high   BTC_low  BTC_close    BTC_volume
# Timestamp
# 2017-08-17 00:00:00   4261.48   4485.39   4200.74    4285.08    795.150377
# 2017-08-18 00:00:00   4285.08   4371.52   3938.77    4108.37   1199.888264
# 2017-08-19 00:00:00   4108.37   4184.69   3850.00    4139.98    381.309763
# 2017-08-20 00:00:00   4120.98   4211.08   4032.62    4086.29    467.083022
# 2017-08-21 00:00:00   4069.13   4119.62   3911.79    4016.00    691.743060
# ...                       ...       ...       ...        ...           ...
# 2024-10-05 00:00:00  62086.00  62370.56  61689.26   62058.00   7807.461410
# 2024-10-06 00:00:00  62058.01  62975.00  61798.97   62819.91   8906.861770
# 2024-10-07 00:00:00  62819.91  64478.19  62128.00   62224.00  25966.185200
# 2024-10-08 00:00:00  62224.01  63200.00  61860.31   62160.49  19702.223710
# 2024-10-09 00:00:00  62160.50  62542.06  62002.50   62509.36   3360.891820
#
# [2611 rows x 5 columns]

# %%
df = pd.concat(objs=[btc, eth, bnb, pepe], axis = 1)

# %%
df
# Out:
#                      BTC_open  BTC_high   BTC_low  BTC_close    BTC_volume  \
# Timestamp
# 2017-08-17 00:00:00   4261.48   4485.39   4200.74    4285.08    795.150377
# 2017-08-18 00:00:00   4285.08   4371.52   3938.77    4108.37   1199.888264
# 2017-08-19 00:00:00   4108.37   4184.69   3850.00    4139.98    381.309763
# 2017-08-20 00:00:00   4120.98   4211.08   4032.62    4086.29    467.083022
# 2017-08-21 00:00:00   4069.13   4119.62   3911.79    4016.00    691.743060
# ...                       ...       ...       ...        ...           ...
# 2024-10-05 00:00:00  62086.00  62370.56  61689.26   62058.00   7807.461410
# 2024-10-06 00:00:00  62058.01  62975.00  61798.97   62819.91   8906.861770
# 2024-10-07 00:00:00  62819.91  64478.19  62128.00   62224.00  25966.185200
# 2024-10-08 00:00:00  62224.01  63200.00  61860.31   62160.49  19702.223710
# 2024-10-09 00:00:00  62160.50  62542.06  62002.50   62509.36   3360.891820
#
# ...

# %%
df_close = [ col for col in df.columns if col.endswith('close')]
df_close
# Out:
# ['BTC_close', 'ETH_close', 'BNB_close', 'PEPE_close']

# %%
df[df_close]
# Out:
#                          BTC_close     ETH_close    BNB_close  PEPE_close
# Timestamp
# 2017-08-17 00:00:00   4285.0800000   302.0000000          NaN         NaN
# 2017-08-18 00:00:00   4108.3700000   293.9600000          NaN         NaN
# 2017-08-19 00:00:00   4139.9800000   290.9100000          NaN         NaN
# 2017-08-20 00:00:00   4086.2900000   299.1000000          NaN         NaN
# 2017-08-21 00:00:00   4016.0000000   323.2900000          NaN         NaN
# ...                            ...           ...          ...         ...
# 2024-10-05 00:00:00  62058.0000000  2414.6600000  563.0000000   0.0000094
# 2024-10-06 00:00:00  62819.9100000  2440.0300000  570.3000000   0.0000102
# 2024-10-07 00:00:00  62224.0000000  2422.7100000  564.3000000   0.0000098
# 2024-10-08 00:00:00  62160.4900000  2440.8900000  580.8000000   0.0000095
# 2024-10-09 00:00:00  62509.3600000  2450.0000000  581.8000000   0.0000098
#
# [2611 rows x 4 columns]

# %%
df[df_close].corr()
# Out:
#             BTC_close  ETH_close  BNB_close  PEPE_close
# BTC_close    1.000000   0.927956   0.917210    0.871316
# ETH_close    0.927956   1.000000   0.945330    0.832346
# BNB_close    0.917210   0.945330   1.000000    0.930962
# PEPE_close   0.871316   0.832346   0.930962    1.000000

# %%
pepe.head()
# Out:
#                      PEPE_open  PEPE_high   PEPE_low  PEPE_close  \
# Timestamp
# 2023-05-05 00:00:00  0.0000020  0.0000044  0.0000020   0.0000037
# 2023-05-06 00:00:00  0.0000037  0.0000039  0.0000023   0.0000026
# 2023-05-07 00:00:00  0.0000026  0.0000031  0.0000024   0.0000028
# 2023-05-08 00:00:00  0.0000028  0.0000028  0.0000015   0.0000019
# 2023-05-09 00:00:00  0.0000019  0.0000021  0.0000017   0.0000020
#
#                                  PEPE_volume
# Timestamp
# 2023-05-05 00:00:00   46108639000543.0000000
# 2023-05-06 00:00:00  108184587925547.0000000
# 2023-05-07 00:00:00   65077437336487.0000000
# 2023-05-08 00:00:00  140237460567381.0000000
# 2023-05-09 00:00:00   84408522428236.0000000

# %%
pd.set_option('display.float_format', lambda x: f'{x: .7f}')

# %%
pepe
# Out:
#                           Open       High        Low      Close  \
# Timestamp
# 2023-05-05 00:00:00  0.0000020  0.0000044  0.0000020  0.0000037
# 2023-05-06 00:00:00  0.0000037  0.0000039  0.0000023  0.0000026
# 2023-05-07 00:00:00  0.0000026  0.0000031  0.0000024  0.0000028
# 2023-05-08 00:00:00  0.0000028  0.0000028  0.0000015  0.0000019
# 2023-05-09 00:00:00  0.0000019  0.0000021  0.0000017  0.0000020
# ...                        ...        ...        ...        ...
# 2024-10-05 00:00:00  0.0000094  0.0000096  0.0000092  0.0000094
# 2024-10-06 00:00:00  0.0000094  0.0000103  0.0000092  0.0000102
# 2024-10-07 00:00:00  0.0000102  0.0000108  0.0000098  0.0000098
# 2024-10-08 00:00:00  0.0000098  0.0000101  0.0000093  0.0000095
# 2024-10-09 00:00:00  0.0000095  0.0000098  0.0000094  0.0000098
#
#                                       Volume
# Timestamp
# 2023-05-05 00:00:00   46108639000543.0000000
# 2023-05-06 00:00:00  108184587925547.0000000
# ...

# %%
pepe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 524 entries, 2023-05-05 00:00:00 to 2024-10-09 00:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    524 non-null    float64
#  1   High    524 non-null    float64
#  2   Low     524 non-null    float64
#  3   Close   524 non-null    float64
#  4   Volume  524 non-null    float64
# dtypes: float64(5)
# memory usage: 24.6+ KB

# %%
pepe.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
#pepe_9 = pepe[(pepe.index.month == 6) & (pepe.index.year == 2024)]
pepe_9 = pepe[(pepe.index.month == 9) & (pepe.index.year == 2024)]
pepe_9
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-06d060d7eddb> in <cell line: 2>()
#       1 #pepe_9 = pepe[(pepe.index.month == 6) & (pepe.index.year == 2024)]
# ----> 2 pepe_9 = pepe[(pepe.Index.month == 9) & (pepe.index.year == 2024)]
#       3 pepe_9
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Index'

# %%
pepe.index =  pd.to_datetime(pepe.index)

# %%
pepe_9 = pepe[(pepe.index.month == 9) & (pepe.index.year == 2024)]
pepe_9
# Out:
#                  Open       High        Low      Close                  Volume
# Timestamp
# 2024-09-01  0.0000076  0.0000076  0.0000071  0.0000071  13434534390703.0000000
# 2024-09-02  0.0000071  0.0000077  0.0000071  0.0000076  15867883282559.0000000
# 2024-09-03  0.0000076  0.0000078  0.0000072  0.0000073  11622079536686.0000000
# 2024-09-04  0.0000073  0.0000075  0.0000068  0.0000073  22387905167693.0000000
# 2024-09-05  0.0000074  0.0000074  0.0000070  0.0000071  11308329658126.0000000
# 2024-09-06  0.0000071  0.0000073  0.0000063  0.0000066  23776934439331.0000000
# 2024-09-07  0.0000066  0.0000070  0.0000066  0.0000068  13494155019632.0000000
# 2024-09-08  0.0000068  0.0000074  0.0000067  0.0000071  17456685657848.0000000
# 2024-09-09  0.0000071  0.0000076  0.0000069  0.0000074  21404330033392.0000000
# 2024-09-10  0.0000074  0.0000076  0.0000073  0.0000075  18520744244221.0000000
# 2024-09-11  0.0000075  0.0000075  0.0000070  0.0000072  20894540166619.0000000
# ...

# %%
pepe_8 = pepe[(pepe.index.month == 8) & (pepe.index.year == 2024)]
pepe_8
# Out:
#                  Open       High        Low      Close  \
# Timestamp
# 2024-08-01  0.0000110  0.0000111  0.0000097  0.0000105
# 2024-08-02  0.0000105  0.0000106  0.0000092  0.0000093
# 2024-08-03  0.0000093  0.0000096  0.0000083  0.0000086
# 2024-08-04  0.0000086  0.0000088  0.0000077  0.0000081
# 2024-08-05  0.0000081  0.0000083  0.0000058  0.0000070
# 2024-08-06  0.0000070  0.0000082  0.0000070  0.0000077
# 2024-08-07  0.0000077  0.0000084  0.0000073  0.0000074
# 2024-08-08  0.0000074  0.0000089  0.0000072  0.0000088
# 2024-08-09  0.0000088  0.0000090  0.0000083  0.0000085
# 2024-08-10  0.0000085  0.0000087  0.0000083  0.0000084
# 2024-08-11  0.0000084  0.0000088  0.0000076  0.0000077
# 2024-08-12  0.0000077  0.0000085  0.0000077  0.0000082
# 2024-08-13  0.0000082  0.0000084  0.0000079  0.0000082
# 2024-08-14  0.0000082  0.0000085  0.0000079  0.0000080
# 2024-08-15  0.0000080  0.0000081  0.0000072  0.0000074
# 2024-08-16  0.0000074  0.0000076  0.0000069  0.0000072
# ...

# %%
pepe8_9 = pd.concat(objs=[pepe_8, pepe_9], axis = 0) #tutaj połączone pionowo
pepe8_9
# Out:
#                  Open       High        Low      Close  \
# Timestamp
# 2024-08-01  0.0000110  0.0000111  0.0000097  0.0000105
# 2024-08-02  0.0000105  0.0000106  0.0000092  0.0000093
# 2024-08-03  0.0000093  0.0000096  0.0000083  0.0000086
# 2024-08-04  0.0000086  0.0000088  0.0000077  0.0000081
# 2024-08-05  0.0000081  0.0000083  0.0000058  0.0000070
# ...               ...        ...        ...        ...
# 2024-09-26  0.0000085  0.0000097  0.0000082  0.0000095
# 2024-09-27  0.0000095  0.0000109  0.0000094  0.0000107
# 2024-09-28  0.0000107  0.0000116  0.0000106  0.0000114
# 2024-09-29  0.0000114  0.0000120  0.0000110  0.0000113
# 2024-09-30  0.0000113  0.0000115  0.0000103  0.0000105
#
#                              Volume
# Timestamp
# 2024-08-01   26994153329356.0000000
# 2024-08-02   28033167875062.0000000
# 2024-08-03   30164160311839.0000000
# 2024-08-04   39535839775128.0000000
# 2024-08-05  132175251906618.0000000
# ...                             ...
# ...
