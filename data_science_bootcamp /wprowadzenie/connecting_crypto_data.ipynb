# %% [markdown]
# <a href="https://colab.research.google.com/github/rafpank/Colab/blob/main/data_science_bootcamp%20/wprowadzenie/connecting_crypto_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
url = 'https://api.binance.com/api/v3/ticker/price?symbol=BTCUSDT'
response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'code': 0, 'msg': "Service unavailable from a restricted location according to 'b. Eligibility' in https://www.binance.com/en/terms. Please contact customer service if you believe you received this message in error."}

# %%
df = pd.read_csv('btc.csv')
df
# Out:
#                 Timestamp      Open      High       Low     Close  \
# 0     2017-08-17 00:00:00   4261.48   4485.39   4200.74   4285.08
# 1     2017-08-18 00:00:00   4285.08   4371.52   3938.77   4108.37
# 2     2017-08-19 00:00:00   4108.37   4184.69   3850.00   4139.98
# 3     2017-08-20 00:00:00   4120.98   4211.08   4032.62   4086.29
# 4     2017-08-21 00:00:00   4069.13   4119.62   3911.79   4016.00
# ...                   ...       ...       ...       ...       ...
# 2606  2024-10-05 00:00:00  62086.00  62370.56  61689.26  62058.00
# 2607  2024-10-06 00:00:00  62058.01  62975.00  61798.97  62819.91
# 2608  2024-10-07 00:00:00  62819.91  64478.19  62128.00  62224.00
# 2609  2024-10-08 00:00:00  62224.01  63200.00  61860.31  62160.49
# 2610  2024-10-09 00:00:00  62160.50  62542.06  62002.50  62509.36
#
#             Volume
# 0       795.150377
# 1      1199.888264
# 2       381.309763
# 3       467.083022
# 4       691.743060
# ...            ...
# 2606   7807.461410
# ...

# %%
bnb = pd.read_csv('bnb.csv')
eth = pd.read_csv('eth.csv')
pepe = pd.read_csv('pepe.csv')

# %%
df.set_index('Timestamp', inplace=True)
df
# Out:
#                          Open      High       Low     Close        Volume
# Timestamp
# 2017-08-17 00:00:00   4261.48   4485.39   4200.74   4285.08    795.150377
# 2017-08-18 00:00:00   4285.08   4371.52   3938.77   4108.37   1199.888264
# 2017-08-19 00:00:00   4108.37   4184.69   3850.00   4139.98    381.309763
# 2017-08-20 00:00:00   4120.98   4211.08   4032.62   4086.29    467.083022
# 2017-08-21 00:00:00   4069.13   4119.62   3911.79   4016.00    691.743060
# ...                       ...       ...       ...       ...           ...
# 2024-10-05 00:00:00  62086.00  62370.56  61689.26  62058.00   7807.461410
# 2024-10-06 00:00:00  62058.01  62975.00  61798.97  62819.91   8906.861770
# 2024-10-07 00:00:00  62819.91  64478.19  62128.00  62224.00  25966.185200
# 2024-10-08 00:00:00  62224.01  63200.00  61860.31  62160.49  19702.223710
# 2024-10-09 00:00:00  62160.50  62542.06  62002.50  62509.36   3360.891820
#
# [2611 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2611 entries, 2017-08-17 00:00:00 to 2024-10-09 00:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2611 non-null   float64
#  1   High    2611 non-null   float64
#  2   Low     2611 non-null   float64
#  3   Close   2611 non-null   float64
#  4   Volume  2611 non-null   float64
# dtypes: float64(5)
# memory usage: 122.4+ KB

# %%
eth
# Out:
#                 Timestamp     Open     High      Low    Close        Volume
# 0     2017-08-17 00:00:00   301.13   312.18   298.00   302.00    7030.71034
# 1     2017-08-18 00:00:00   302.00   311.79   283.94   293.96    9537.84646
# 2     2017-08-19 00:00:00   293.31   299.90   278.00   290.91    2146.19773
# 3     2017-08-20 00:00:00   289.41   300.53   282.85   299.10    2510.13871
# 4     2017-08-21 00:00:00   299.10   346.52   294.60   323.29    5219.44542
# ...                   ...      ...      ...      ...      ...           ...
# 2606  2024-10-05 00:00:00  2414.41  2428.23  2390.05  2414.66  103740.23160
# 2607  2024-10-06 00:00:00  2414.66  2457.80  2407.00  2440.03  105752.70960
# 2608  2024-10-07 00:00:00  2440.02  2521.00  2403.00  2422.71  300459.54070
# 2609  2024-10-08 00:00:00  2422.70  2466.66  2401.18  2440.89  201358.33120
# 2610  2024-10-09 00:00:00  2440.88  2473.61  2427.44  2450.00   47275.35550
#
# [2611 rows x 6 columns]

# %%
eth.set_index('Timestamp', inplace=True)
eth
# Out:
#                         Open     High      Low    Close        Volume
# Timestamp
# 2017-08-17 00:00:00   301.13   312.18   298.00   302.00    7030.71034
# 2017-08-18 00:00:00   302.00   311.79   283.94   293.96    9537.84646
# 2017-08-19 00:00:00   293.31   299.90   278.00   290.91    2146.19773
# 2017-08-20 00:00:00   289.41   300.53   282.85   299.10    2510.13871
# 2017-08-21 00:00:00   299.10   346.52   294.60   323.29    5219.44542
# ...                      ...      ...      ...      ...           ...
# 2024-10-05 00:00:00  2414.41  2428.23  2390.05  2414.66  103740.23160
# 2024-10-06 00:00:00  2414.66  2457.80  2407.00  2440.03  105752.70960
# 2024-10-07 00:00:00  2440.02  2521.00  2403.00  2422.71  300459.54070
# 2024-10-08 00:00:00  2422.70  2466.66  2401.18  2440.89  201358.33120
# 2024-10-09 00:00:00  2440.88  2473.61  2427.44  2450.00   47275.35550
#
# [2611 rows x 5 columns]

# %%
bnb.set_index('Timestamp', inplace=True)
bnb
# Out:
#                          Open      High       Low     Close      Volume
# Timestamp
# 2017-11-06 00:00:00    1.5000    1.7990    0.5000    1.5710  120615.340
# 2017-11-07 00:00:00    1.5710    1.8000    1.5389    1.8000  134129.730
# 2017-11-08 00:00:00    1.7901    1.9900    1.7479    1.9889  347290.260
# 2017-11-09 00:00:00    1.9781    2.1997    1.9000    1.9900  287037.200
# 2017-11-10 00:00:00    1.9900    2.0200    1.6019    1.7133  484658.900
# ...                       ...       ...       ...       ...         ...
# 2024-10-05 00:00:00  555.3000  565.2000  551.6000  563.0000  124906.382
# 2024-10-06 00:00:00  563.0000  571.9000  561.1000  570.3000  106787.340
# 2024-10-07 00:00:00  570.4000  581.8000  563.5000  564.3000  213046.676
# 2024-10-08 00:00:00  564.4000  586.8000  559.5000  580.8000  286276.177
# 2024-10-09 00:00:00  580.8000  583.1000  573.1000  581.8000  106837.222
#
# [2530 rows x 5 columns]

# %%
pepe.set_index('Timestamp', inplace=True)
pepe
# Out:
#                          Open      High       Low     Close        Volume
# Timestamp
# 2023-05-05 00:00:00  0.000002  0.000004  0.000002  0.000004  4.610864e+13
# 2023-05-06 00:00:00  0.000004  0.000004  0.000002  0.000003  1.081846e+14
# 2023-05-07 00:00:00  0.000003  0.000003  0.000002  0.000003  6.507744e+13
# 2023-05-08 00:00:00  0.000003  0.000003  0.000002  0.000002  1.402375e+14
# 2023-05-09 00:00:00  0.000002  0.000002  0.000002  0.000002  8.440852e+13
# ...                       ...       ...       ...       ...           ...
# 2024-10-05 00:00:00  0.000009  0.000010  0.000009  0.000009  2.183760e+13
# 2024-10-06 00:00:00  0.000009  0.000010  0.000009  0.000010  2.988488e+13
# 2024-10-07 00:00:00  0.000010  0.000011  0.000010  0.000010  4.398794e+13
# 2024-10-08 00:00:00  0.000010  0.000010  0.000009  0.000010  2.833179e+13
# 2024-10-09 00:00:00  0.000010  0.000010  0.000009  0.000010  5.703468e+12
#
# [524 rows x 5 columns]

# %%
pepe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 524 entries, 2023-05-05 00:00:00 to 2024-10-09 00:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    524 non-null    float64
#  1   High    524 non-null    float64
#  2   Low     524 non-null    float64
#  3   Close   524 non-null    float64
#  4   Volume  524 non-null    float64
# dtypes: float64(5)
# memory usage: 40.7+ KB

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2611 entries, 2017-08-17 00:00:00 to 2024-10-09 00:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2611 non-null   float64
#  1   High    2611 non-null   float64
#  2   Low     2611 non-null   float64
#  3   Close   2611 non-null   float64
#  4   Volume  2611 non-null   float64
# dtypes: float64(5)
# memory usage: 122.4+ KB

# %%
df.columns = ['BTC_' + col.lower() for col in df.columns]
df
# Out:
#                      BTC_open  BTC_high   BTC_low  BTC_close    BTC_volume
# Timestamp
# 2017-08-17 00:00:00   4261.48   4485.39   4200.74    4285.08    795.150377
# 2017-08-18 00:00:00   4285.08   4371.52   3938.77    4108.37   1199.888264
# 2017-08-19 00:00:00   4108.37   4184.69   3850.00    4139.98    381.309763
# 2017-08-20 00:00:00   4120.98   4211.08   4032.62    4086.29    467.083022
# 2017-08-21 00:00:00   4069.13   4119.62   3911.79    4016.00    691.743060
# ...                       ...       ...       ...        ...           ...
# 2024-10-05 00:00:00  62086.00  62370.56  61689.26   62058.00   7807.461410
# 2024-10-06 00:00:00  62058.01  62975.00  61798.97   62819.91   8906.861770
# 2024-10-07 00:00:00  62819.91  64478.19  62128.00   62224.00  25966.185200
# 2024-10-08 00:00:00  62224.01  63200.00  61860.31   62160.49  19702.223710
# 2024-10-09 00:00:00  62160.50  62542.06  62002.50   62509.36   3360.891820
#
# [2611 rows x 5 columns]

# %%
eth.columns = [ 'ETH_' + col.lower() for col in eth.columns]
eth
# Out:
#                      ETH_open  ETH_high  ETH_low  ETH_close    ETH_volume
# Timestamp
# 2017-08-17 00:00:00    301.13    312.18   298.00     302.00    7030.71034
# 2017-08-18 00:00:00    302.00    311.79   283.94     293.96    9537.84646
# 2017-08-19 00:00:00    293.31    299.90   278.00     290.91    2146.19773
# 2017-08-20 00:00:00    289.41    300.53   282.85     299.10    2510.13871
# 2017-08-21 00:00:00    299.10    346.52   294.60     323.29    5219.44542
# ...                       ...       ...      ...        ...           ...
# 2024-10-05 00:00:00   2414.41   2428.23  2390.05    2414.66  103740.23160
# 2024-10-06 00:00:00   2414.66   2457.80  2407.00    2440.03  105752.70960
# 2024-10-07 00:00:00   2440.02   2521.00  2403.00    2422.71  300459.54070
# 2024-10-08 00:00:00   2422.70   2466.66  2401.18    2440.89  201358.33120
# 2024-10-09 00:00:00   2440.88   2473.61  2427.44    2450.00   47275.35550
#
# [2611 rows x 5 columns]

# %%
bnb.columns = [ 'BNB_' + col.lower() for col in bnb.columns]
bnb
# Out:
#                      BNB_open  BNB_high   BNB_low  BNB_close  BNB_volume
# Timestamp
# 2017-11-06 00:00:00    1.5000    1.7990    0.5000     1.5710  120615.340
# 2017-11-07 00:00:00    1.5710    1.8000    1.5389     1.8000  134129.730
# 2017-11-08 00:00:00    1.7901    1.9900    1.7479     1.9889  347290.260
# 2017-11-09 00:00:00    1.9781    2.1997    1.9000     1.9900  287037.200
# 2017-11-10 00:00:00    1.9900    2.0200    1.6019     1.7133  484658.900
# ...                       ...       ...       ...        ...         ...
# 2024-10-05 00:00:00  555.3000  565.2000  551.6000   563.0000  124906.382
# 2024-10-06 00:00:00  563.0000  571.9000  561.1000   570.3000  106787.340
# 2024-10-07 00:00:00  570.4000  581.8000  563.5000   564.3000  213046.676
# 2024-10-08 00:00:00  564.4000  586.8000  559.5000   580.8000  286276.177
# 2024-10-09 00:00:00  580.8000  583.1000  573.1000   581.8000  106837.222
#
# [2530 rows x 5 columns]

# %%
pepe.columns = ['PEPE_' + col.lower() for col in pepe.columns]
pepe.head(10)
# Out:
#                      PEPE_open  PEPE_high  PEPE_low  PEPE_close   PEPE_volume
# Timestamp
# 2023-05-05 00:00:00   0.000002   0.000004  0.000002    0.000004  4.610864e+13
# 2023-05-06 00:00:00   0.000004   0.000004  0.000002    0.000003  1.081846e+14
# 2023-05-07 00:00:00   0.000003   0.000003  0.000002    0.000003  6.507744e+13
# 2023-05-08 00:00:00   0.000003   0.000003  0.000002    0.000002  1.402375e+14
# 2023-05-09 00:00:00   0.000002   0.000002  0.000002    0.000002  8.440852e+13
# 2023-05-10 00:00:00   0.000002   0.000002  0.000002    0.000002  6.237661e+13
# 2023-05-11 00:00:00   0.000002   0.000002  0.000001    0.000001  1.024782e+14
# 2023-05-12 00:00:00   0.000001   0.000002  0.000001    0.000002  1.831172e+14
# 2023-05-13 00:00:00   0.000002   0.000002  0.000002    0.000002  1.608453e+14
# 2023-05-14 00:00:00   0.000002   0.000002  0.000002    0.000002  6.833063e+13
